# %% [markdown]
# # Линейная регрессия: переобучение и регуляризация

# %% [markdown]
# В этом задании мы на примерах увидим, как переобучаются линейные модели, разберем, почему так происходит, и выясним, как диагностировать и контролировать переобучение.
#
# Во всех ячейках, где написан комментарий с инструкциями, нужно написать код, выполняющий эти инструкции. Остальные ячейки с кодом (без комментариев) нужно просто выполнить. Кроме того, в задании требуется отвечать на вопросы; ответы нужно вписывать после выделенного слова "__Ответ:__".

# %%
# !pip install pandas
# !pip install numpy
# !pip install matplotlib
# !pip install scikit-learn
# Out:
# Requirement already satisfied: pandas in ./anaconda3/lib/python3.11/site-packages (2.0.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./anaconda3/lib/python3.11/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in ./anaconda3/lib/python3.11/site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in ./anaconda3/lib/python3.11/site-packages (from pandas) (2023.3)
# Requirement already satisfied: numpy>=1.21.0 in ./anaconda3/lib/python3.11/site-packages (from pandas) (1.24.3)
# Requirement already satisfied: six>=1.5 in ./anaconda3/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: numpy in ./anaconda3/lib/python3.11/site-packages (1.24.3)
# Requirement already satisfied: matplotlib in ./anaconda3/lib/python3.11/site-packages (3.7.2)
# Requirement already satisfied: contourpy>=1.0.1 in ./anaconda3/lib/python3.11/site-packages (from matplotlib) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in ./anaconda3/lib/python3.11/site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in ./anaconda3/lib/python3.11/site-packages (from matplotlib) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in ./anaconda3/lib/python3.11/site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: numpy>=1.20 in ./anaconda3/lib/python3.11/site-packages (from matplotlib) (1.24.3)
# Requirement already satisfied: packaging>=20.0 in ./anaconda3/lib/python3.11/site-packages (from matplotlib) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in ./anaconda3/lib/python3.11/site-packages (from matplotlib) (10.0.1)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in ./anaconda3/lib/python3.11/site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in ./anaconda3/lib/python3.11/site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in ./anaconda3/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Requirement already satisfied: scikit-learn in ./anaconda3/lib/python3.11/site-packages (1.3.0)
# Requirement already satisfied: numpy>=1.17.3 in ./anaconda3/lib/python3.11/site-packages (from scikit-learn) (1.24.3)
# Requirement already satisfied: scipy>=1.5.0 in ./anaconda3/lib/python3.11/site-packages (from scikit-learn) (1.11.1)
# Requirement already satisfied: joblib>=1.1.1 in ./anaconda3/lib/python3.11/site-packages (from scikit-learn) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in ./anaconda3/lib/python3.11/site-packages (from scikit-learn) (2.2.0)

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline

# %% [markdown]
# Мы будем работать с датасетом __"bikes_rent.csv"__, в котором по дням записаны календарная информация и погодные условия, характеризующие автоматизированные пункты проката велосипедов, а также число прокатов в этот день. Последнее мы будем предсказывать; таким образом, мы будем решать задачу регрессии.

# %% [markdown]
# ### Знакомство с данными

# %% [markdown]
# ## Задание 1

# %% [markdown]
# Загрузите датасет с помощью функции __pandas.read_csv__ в переменную __df__. Выведите первые 5 строчек, чтобы убедиться в корректном считывании данных:

# %%
import pandas as pd
import gdown
url = 'https://drive.google.com/uc?id=1-4wgz9AFXrD3tZfqHJLMhCmy4BUzAX96'

output = 'dataset.csv'

gdown.download(url, output, quiet=False)

df = pd.read_csv(output)

print(df.head())
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1-4wgz9AFXrD3tZfqHJLMhCmy4BUzAX96
# To: /Users/vika/dataset.csv
# 100%|██████████████████████████████████████| 50.3k/50.3k [00:00<00:00, 2.67MB/s]
#    season  yr  mnth  holiday  weekday  workingday  weathersit       temp  \
# 0       1   0     1        0        6           0           2  14.110847
# 1       1   0     1        0        0           0           2  14.902598
# 2       1   0     1        0        1           1           1   8.050924
# 3       1   0     1        0        2           1           1   8.200000
# 4       1   0     1        0        3           1           1   9.305237
#
#       atemp      hum  windspeed(mph)  windspeed(ms)   cnt
# 0  18.18125  80.5833       10.749882       4.805490   985
# 1  17.68695  69.6087       16.652113       7.443949   801
# 2   9.47025  43.7273       16.636703       7.437060  1349
# 3  10.60610  59.0435       10.739832       4.800998  1562
# 4  11.46350  43.6957       12.522300       5.597810  1600

# %% [markdown]
# Для каждого дня проката известны следующие признаки:
# * _season_: 1 - весна, 2 - лето, 3 - осень, 4 - зима
# * _yr_: 0 - 2011, 1 - 2012
# * _mnth_: от 1 до 12
# * _holiday_: 0 - нет праздника, 1 - есть праздник
# * _weekday_: от 0 до 6
# * _workingday_: 0 - нерабочий день, 1 - рабочий день
# * _weathersit_: оценка благоприятности погоды от 1 (чистый, ясный день) до 4 (ливень, туман)
# * _temp_: температура в Цельсиях
# * _atemp_: температура по ощущениям в Цельсиях
# * _hum_: влажность
# * _windspeed(mph)_: скорость ветра в милях в час
# * _windspeed(ms)_: скорость ветра в метрах в секунду
# * _cnt_: количество арендованных велосипедов (это целевой признак, его мы будем предсказывать)
#
# Итак, у нас есть вещественные, бинарные и номинальные (порядковые) признаки, и со всеми из них можно работать как с вещественными. С номинальныеми признаками тоже можно работать как с вещественными, потому что на них задан порядок. Давайте посмотрим на графиках, как целевой признак зависит от остальных

# %% [markdown]
# Постройте графики зависимостей атрибутов от количества поездок. Другими словами вам нужно построить 12 графиков. На каждом должна быть изображена зависимость очередного атрибута от переменной **cnt**.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.set(style="whitegrid")

fig, axes = plt.subplots(nrows=4, ncols=3, figsize=(15, 20))
fig.suptitle('Зависимость атрибутов от количества поездок', fontsize=16)

attributes = ['season', 'yr', 'mnth', 'holiday', 'weekday', 'workingday', 'weathersit', 'temp', 'atemp', 'hum', 'windspeed(mph)', 'windspeed(ms)']

for i, attr in enumerate(attributes):
    row = i // 3
    col = i % 3
    sns.scatterplot(x='cnt', y=attr, data=df, ax=axes[row, col])
    axes[row, col].set_title(f'Count vs {attr.capitalize()}', fontsize=12)
    axes[row, col].set_xlabel('Count', fontsize=10)
    axes[row, col].set_ylabel(attr.capitalize(), fontsize=10)

plt.tight_layout(rect=[0, 0, 1, 0.96])

plt.show()

# %% [markdown]
# __Вопросы:__
# 1. Каков характер зависимости числа прокатов от месяца?
# 1. Укажите один или два признака, от которых число прокатов скорее всего зависит линейно

# %% [raw]
# Відповіді:
# 1.Прокат велосипедів має залежність від сезонності. Тенденція прокату вище у літні місяці, а в інші нижче.
# 2.Число прокатів залежить від температури і температури по відчуттям.

# %% [markdown]
# ## Задание 2
#
# Давайте более строго оценим уровень линейной зависимости между признаками и целевой переменной. Хорошей мерой линейной зависимости между двумя векторами является корреляция Пирсона. Нам уже приходилось иметь с ней дело раньше. Для ее вычисления в pandas можно использовать методы датафрейма: corr и corrwith.

# %% [markdown]
# Посчитайте корреляции всех признаков, кроме последнего, с последним с помощью метода `corrwith`.

# %%
correlations = df.iloc[:, :-1].corrwith(df['cnt'])

print("Корреляции признаков с cnt:")
print(correlations)

numeric_features = df[['temp', 'atemp', 'hum', 'windspeed(mph)', 'windspeed(ms)', 'cnt']]
numeric_correlations = numeric_features.corr()

print("\nКорреляции между вещественными признаками:")
print(numeric_correlations)
# Out:
# Корреляции признаков с cnt:
# season            0.406100
# yr                0.566710
# mnth              0.279977
# holiday          -0.068348
# weekday           0.067443
# workingday        0.061156
# weathersit       -0.297391
# temp              0.627494
# atemp             0.631066
# hum              -0.100659
# windspeed(mph)   -0.234545
# windspeed(ms)    -0.234545
# dtype: float64
#
# Корреляции между вещественными признаками:
#                     temp     atemp       hum  windspeed(mph)  windspeed(ms)  \
# temp            1.000000  0.991702  0.126963       -0.157944      -0.157944
# atemp           0.991702  1.000000  0.139988       -0.183643      -0.183643
# hum             0.126963  0.139988  1.000000       -0.248489      -0.248489
# windspeed(mph) -0.157944 -0.183643 -0.248489        1.000000       1.000000
# windspeed(ms)  -0.157944 -0.183643 -0.248489        1.000000       1.000000
# cnt             0.627494  0.631066 -0.100659       -0.234545      -0.234545
#
#                      cnt
# temp            0.627494
# atemp           0.631066
# hum            -0.100659
# windspeed(mph) -0.234545
# windspeed(ms)  -0.234545
# cnt             1.000000

# %% [markdown]
# В выборке есть признаки, коррелирующие с целевым, а значит, задачу можно решать линейными методами.

# %% [markdown]
# По графикам видно, что некоторые признаки похожи друг на друга. Поэтому давайте также посчитаем корреляции между вещественными признаками.

# %% [markdown]
# ## Задание 3
#
# Посчитайте попарные корреляции между признаками temp, atemp, hum, windspeed(mph), windspeed(ms) и cnt
# с помощью метода corr:

# %%
correlation_matrix = df[['temp', 'atemp', 'hum', 'windspeed(mph)', 'windspeed(ms)', 'cnt']].corr()

print("Матрица попарных корреляций:")
print(correlation_matrix)

print("\nСредние значения признаков:")
print(df[['temp', 'atemp', 'hum', 'windspeed(mph)', 'windspeed(ms)', 'cnt']].mean())
# Out:
# Матрица попарных корреляций:
#                     temp     atemp       hum  windspeed(mph)  windspeed(ms)  \
# temp            1.000000  0.991702  0.126963       -0.157944      -0.157944
# atemp           0.991702  1.000000  0.139988       -0.183643      -0.183643
# hum             0.126963  0.139988  1.000000       -0.248489      -0.248489
# windspeed(mph) -0.157944 -0.183643 -0.248489        1.000000       1.000000
# windspeed(ms)  -0.157944 -0.183643 -0.248489        1.000000       1.000000
# cnt             0.627494  0.631066 -0.100659       -0.234545      -0.234545
#
#                      cnt
# temp            0.627494
# atemp           0.631066
# hum            -0.100659
# windspeed(mph) -0.234545
# windspeed(ms)  -0.234545
# cnt             1.000000
#
# Средние значения признаков:
# temp                20.310776
# atemp               23.717699
# hum                 62.789406
# windspeed(mph)      12.762576
# windspeed(ms)        5.705220
# cnt               4504.348837
# dtype: float64

# %% [markdown]
# На диагоналях, как и полагается, стоят единицы. Однако в матрице имеются еще две пары сильно коррелирующих столбцов: temp и atemp (коррелируют по своей природе) и два windspeed (потому что это просто перевод одних единиц в другие). Далее мы увидим, что этот факт негативно сказывается на обучении линейной модели.

# %% [markdown]
# Напоследок посмотрим средние признаков (метод mean), чтобы оценить масштаб признаков и доли 1 у бинарных признаков.

# %% [markdown]
# ## Задание 4
#
# Выведите средние признаков

# %%
print("\nСредние значения признаков:")
print(df[['temp', 'atemp', 'hum', 'windspeed(mph)', 'windspeed(ms)', 'cnt']].mean())
# Out:
# Средние значения признаков:
# temp                20.310776
# atemp               23.717699
# hum                 62.789406
# windspeed(mph)      12.762576
# windspeed(ms)        5.705220
# cnt               4504.348837
# dtype: float64

# %% [markdown]
# Признаки имеют разный масштаб, значит для дальнейшей работы нам лучше нормировать матрицу объекты-признаки.

# %% [markdown]
# ### Проблема первая: коллинеарные признаки

# %% [markdown]
# Итак, в наших данных один признак дублирует другой, и есть еще два очень похожих. Конечно, мы могли бы сразу удалить дубликаты, но давайте посмотрим, как бы происходило обучение модели, если бы мы не заметили эту проблему.
#
# Для начала проведем масштабирование, или стандартизацию признаков: из каждого признака вычтем его среднее и поделим на стандартное отклонение. Это можно сделать с помощью метода scale.
#
# Кроме того, нужно перемешать выборку, это потребуется для кросс-валидации.

# %%
from sklearn.preprocessing import scale
from sklearn.utils import shuffle

# %%
print("\nСредние значения признаков:")
print(df[['temp', 'atemp', 'hum', 'windspeed(mph)', 'windspeed(ms)', 'cnt']].mean())

# Устранение проблемы коллинеарных признаков
# Масштабирование признаков
df_scaled = df[['temp', 'atemp', 'hum', 'windspeed(mph)', 'windspeed(ms)', 'cnt']].copy()
df_scaled[['temp', 'atemp', 'hum', 'windspeed(mph)', 'windspeed(ms)']] = scale(df_scaled[['temp', 'atemp', 'hum', 'windspeed(mph)', 'windspeed(ms)']])

df_shuffled = shuffle(df_scaled, random_state=42)

print("\nСредние значения признаков после масштабирования и перемешивания:")
print(df_shuffled[['temp', 'atemp', 'hum', 'windspeed(mph)', 'windspeed(ms)', 'cnt']].mean())
# Out:
# Средние значения признаков:
# temp                20.310776
# atemp               23.717699
# hum                 62.789406
# windspeed(mph)      12.762576
# windspeed(ms)        5.705220
# cnt               4504.348837
# dtype: float64
#
# Средние значения признаков после масштабирования и перемешивания:
# temp             -1.166418e-16
# atemp            -2.527238e-16
# hum               3.207648e-16
# windspeed(mph)   -1.166418e-16
# windspeed(ms)     3.402051e-16
# cnt               4.504349e+03
# dtype: float64

# %% [markdown]
# Давайте обучим линейную регрессию на наших данных и посмотрим на веса признаков.

# %%
from sklearn.linear_model import LinearRegression

# %%
print("\nСредние значения признаков:")
print(df[['temp', 'atemp', 'hum', 'windspeed(mph)', 'windspeed(ms)', 'cnt']].mean())

df_scaled = df[['temp', 'atemp', 'hum', 'windspeed(mph)', 'windspeed(ms)', 'cnt']].copy()
df_scaled[['temp', 'atemp', 'hum', 'windspeed(mph)', 'windspeed(ms)']] = (df_scaled[['temp', 'atemp', 'hum', 'windspeed(mph)', 'windspeed(ms)']] - df_scaled[['temp', 'atemp', 'hum', 'windspeed(mph)', 'windspeed(ms)']].mean()) / df_scaled[['temp', 'atemp', 'hum', 'windspeed(mph)', 'windspeed(ms)']].std()

df_shuffled = shuffle(df_scaled, random_state=42)

X = df_shuffled[['temp', 'atemp', 'hum', 'windspeed(mph)', 'windspeed(ms)']]
y = df_shuffled["cnt"]

linear_reg = LinearRegression()
linear_reg.fit(X, y)

weights = linear_reg.coef_
intercept = linear_reg.intercept_

print("\nВеса признаков:")
for feature, weight in zip(['temp', 'atemp', 'hum', 'windspeed(mph)', 'windspeed(ms)'], weights):
    print(f"{feature}: {weight}")

print("\nСвободный член (intercept):", intercept)
# Out:
# Средние значения признаков:
# temp                20.310776
# atemp               23.717699
# hum                 62.789406
# windspeed(mph)      12.762576
# windspeed(ms)        5.705220
# cnt               4504.348837
# dtype: float64
#
# Веса признаков:
# temp: 385.9520560988876
# atemp: 838.0843438736193
# hum: -448.45408186372873
# windspeed(mph): 2141340398410.6833
# windspeed(ms): -2141340398761.6165
#
# Свободный член (intercept): 4504.349815474032

# %% [markdown]
# ## Задание 5
#
# Создайте объект линейного регрессора, обучите его на всех данных и выведите веса модели (веса хранятся в переменной `coef_` класса регрессора). Можно выводить пары (название признака, вес), воспользовавшись функцией `zip`, встроенной в язык python. Названия признаков хранятся в переменной `df.columns`.

# %%
linear_regressor = LinearRegression()

X = df[df.columns[:-1]]
y = df["cnt"]

linear_regressor.fit(X, y)

feature_weights = list(zip(df.columns[:-1], linear_regressor.coef_))
print("Веса признаков после обучения линейной регрессии:")
print(feature_weights)
# Out:
# Веса признаков после обучения линейной регрессии:
# [('season', 514.2759557467537), ('yr', 2043.9347670617624), ('mnth', -40.96322785851248), ('holiday', -519.3881744852526), ('weekday', 68.49432834257063), ('workingday', 121.29221642499976), ('weathersit', -606.4525900980153), ('temp', 48.99433235844276), ('atemp', 71.91632952874704), ('hum', -10.23065251478647), ('windspeed(mph)', 2400972111443.79), ('windspeed(ms)', -5370974613384.558)]

# %% [markdown]
# Мы видим, что веса при линейно-зависимых признаках по модулю значительно больше, чем при других признаках. Чтобы понять, почему так произошло, вспомним аналитическую формулу, по которой вычисляются веса линейной модели в методе наименьших квадратов:
#
# $$w = (X^TX)^{-1} X^T y$$
#
# Если в $X$ есть коллинеарные (линейно-зависимые) столбцы, матрица $X^TX$ становится вырожденной, и формула перестает быть корректной. Чем более зависимы признаки, тем меньше определитель этой матрицы и тем хуже аппроксимация $Xw \approx y$. Такая ситуацию называют _проблемой мультиколлинеарности_.

# %% [markdown]
# С парой (temp, atemp) чуть менее коррелирующих переменных такого не произошло, однако на практике всегда стоит внимательно следить за коэффициентами при похожих признаках.

# %% [markdown]
# Для того, чтобы решить проблему мультиколлинеарности нужно воспользоваться регуляризатором. К оптимизируемому функционалу прибавляют $L_1$ или $L_2$ норму весов, умноженную на коэффициент регуляризации $\alpha$. В первом случае метод называется Lasso, а во втором --- Ridge.

# %% [markdown]
# ### Задание 6
# Давайте попробуем обучить линейные модели с $L_1$ и $L_2$-регуляризацией, а далее сравним их веса. Обучите регрессоры Ridge и Lasso с параметрами по умолчанию и убедитесь, что проблема с весами решилась.

# %% [markdown]
# Обучите линейную модель с $L_1$-регуляризацией (класс Lasso) и выведите веса

# %%
from sklearn.linear_model import Lasso

df_shuffled = shuffle(df, random_state=42)
X = scale(df_shuffled[df_shuffled.columns[:-1]])
y = df_shuffled["cnt"]

# Обучите модель Lasso
lasso_reg = Lasso()
lasso_reg.fit(X, y)

print("Lasso Regression Weights:")
print(dict(zip(df.columns, lasso_reg.coef_)))
# Out:
# Lasso Regression Weights:
# {'season': 560.2416160308861, 'yr': 1019.4634940657196, 'mnth': -128.73062703678696, 'holiday': -86.15278133371106, 'weekday': 137.34789390496314, 'workingday': 55.21237064135668, 'weathersit': -332.3698569623487, 'temp': 376.3632362096943, 'atemp': 576.530793504555, 'hum': -144.12915500348583, 'windspeed(mph)': -197.1396894024843, 'windspeed(ms)': -2.8051404183533485e-08}

# %% [markdown]
# Обучите линейную модель с $L_2$-регуляризацией (класс Ridge) и выведите веса

# %%
from sklearn.linear_model import Ridge


df_shuffled = shuffle(df, random_state=42)
X = scale(df_shuffled[df_shuffled.columns[:-1]])
y = df_shuffled["cnt"]

# Обучите модель Ridge
ridge_reg = Ridge()
ridge_reg.fit(X, y)

print("Ridge Regression Weights:")
print(dict(zip(df.columns, ridge_reg.coef_)))
# Out:
# Ridge Regression Weights:
# {'season': 563.0645722520181, 'yr': 1018.9483787875305, 'mnth': -131.87332028247718, 'holiday': -86.74609799709232, 'weekday': 138.00511117871918, 'workingday': 55.90311037506468, 'weathersit': -332.3497884990738, 'temp': 386.45788919190795, 'atemp': 566.347047060067, 'hum': -145.07132729867192, 'windspeed(mph)': -99.25944108176553, 'windspeed(ms)': -99.25944115436688}

# %% [markdown]
# ### Задание 7
#
# В отличие от $L_2$-регуляризации, $L_1$ обнуляет веса при некоторых признаках Давайте пронаблюдаем, как меняются веса при увеличении коэффициента регуляризации $\alpha$.

# %% [markdown]
# Для каждого значения коэффициента из `alphas` обучите регрессор `Lasso` и запишите веса список `coefs_lasso`, а затем обучите `Ridge` и запишите веса в список`coefs_ridge`. Конвертируйте полученные списки в `np.array`.

# %%
from sklearn.linear_model import Lasso, Ridge

columns = df.columns

df_shuffled = shuffle(df, random_state=42)
X = scale(df_shuffled[df_shuffled.columns[:-1]])
y = df_shuffled["cnt"]

alphas = np.arange(1, 500, 50)

coefs_lasso = []
coefs_ridge = []

for alpha in alphas:
    lasso_regressor = Lasso(alpha=alpha)
    lasso_regressor.fit(X, y)
    coefs_lasso.append(lasso_regressor.coef_)

    ridge_regressor = Ridge(alpha=alpha)
    ridge_regressor.fit(X, y)
    coefs_ridge.append(ridge_regressor.coef_)

coefs_lasso = np.array(coefs_lasso)
coefs_ridge = np.array(coefs_ridge)

plt.figure(figsize=(12, 8))
for i in range(coefs_lasso.shape[1]):
    plt.plot(alphas, coefs_lasso[:, i], label=f'Lasso: {columns[i]}')
    plt.plot(alphas, coefs_ridge[:, i], label=f'Ridge: {columns[i]}', linestyle='dashed')

plt.xlabel('Alpha')
plt.ylabel('Weight Value')
plt.title('Lasso and Ridge Regression Coefficients vs Alpha')
plt.legend()
plt.show()

# %% [markdown]
# Проанализируйте динамику весов при увеличении параметра регуляризации:

# %%
plt.figure(figsize=(8, 5))

for coef, feature in zip(coefs_lasso.T, df.columns):
    plt.plot(alphas, coef, label=feature, color=np.random.rand(3))

plt.legend(loc="upper right", bbox_to_anchor=(1.4, 0.95))
plt.xlabel("alpha")
plt.ylabel("feature weight")
plt.title("Lasso")

plt.figure(figsize=(8, 5))
for coef, feature in zip(coefs_ridge.T, df.columns):
    plt.plot(alphas, coef, label=feature, color=np.random.rand(3))

plt.legend(loc="upper right", bbox_to_anchor=(1.4, 0.95))
plt.xlabel("alpha")
plt.ylabel("feature weight")
plt.title("Ridge")

plt.show()

# %% [markdown]
# Проанализируйте графики и дайте ответы на следующие вопросы.
#
# 1. Какой регуляризатор (Ridge или Lasso) агрессивнее уменьшает веса при одном и том же alpha?
# 1. Что произойдет с весами Lasso, если alpha сделать очень большим? Поясните, почему так происходит.
# 1. Можно ли утверждать, что `Lasso` исключает один из признаков `windspeed` при любом значении `alpha > 0`? А Ridge? Считается, что регуляризатор исключает признак, если коэффициент при нем меньше $10^{-3}$.
# 1. Какой из регуляризаторов подойдет для отбора неинформативных признаков?

# %% [raw]
# 1. Lasso більш агресивно зменшує ваги у тому самому alpha у порівнянні з Ridge.
# 2. При дуже великих значеннях alpha ваги ознак Lasso стають рівними нулю. Це відбувається через те, що L1-регуляризація в Lasso штрафує модель за суму абсолютних значень ваг, і за досить великого alpha модель прагне мінімізувати цю суму, що призводить до обнулення ваг.
# 3. Так, можна стверджувати, що Lasso виключає одну з ознак windspeed за будь-якого значення alpha > 0. Це видно на графіках, де вага однієї з ознак windspeed стає рівною нулю. У той час як Ridge через використання L2-регуляризації не виключає ознаки повністю, але може зменшувати їх ваги до значень близьких до нуля.
# 4. Lasso підходить краще для відбору неінформативних ознак, оскільки він може обнулювати ваги ознак. Ridge, хоч і зменшує ваги, не обнуляє їх повністю. Таким чином, якщо мета - відбір ознак, Lasso краще.

# %% [markdown]
# ### Задание 8
#
# Далее будем работать с `Lasso`.
#
# Итак, мы видим, что при изменении alpha модель по-разному подбирает коэффициенты признаков. Нам нужно выбрать наилучшее alpha.
#
# Для этого, во-первых, нам нужна метрика качества. Будем использовать в качестве метрики сам оптимизируемый функционал метода наименьших квадратов, то есть `Mean Square Error`.
#
# Во-вторых, нужно понять, на каких данных эту метрику считать. Нельзя выбирать `alpha` по значению MSE на обучающей выборке, потому что тогда мы не сможем оценить, как модель будет делать предсказания на новых для нее данных. Если мы выберем одно разбиение выборки на обучающую и тестовую (это называется holdout), то настроимся на конкретные "новые" данные, и вновь можем переобучиться. Поэтому будем делать несколько разбиений выборки, на каждом пробовать разные значения alpha, а затем усреднять MSE. Удобнее всего делать такие разбиения кросс-валидацией, то есть разделить выборку на $K$ часте, и каждый раз брать одну из них как тестовую, а из оставшихся блоков составлять обучающую выборку.

# %% [markdown]
# Делать кросс-валидацию для регрессии в sklearn совсем просто: для этого есть специальный регрессор, __LassoCV__, который берет на вход список из alpha и для каждого из них вычисляет MSE на кросс-валидации. После обучения (если оставить параметр cv=3 по умолчанию) регрессор будет содержать переменную __mse\_path\___, матрицу размера len(alpha) x k, k = 3 (число блоков в кросс-валидации), содержащую значения MSE на тесте для соответствующих запусков. Кроме того, в переменной alpha\_ будет храниться выбранное значение параметра регуляризации, а в coef\_, традиционно, обученные веса, соответствующие этому alpha_.
#
# Обратите внимание, что регрессор может менять порядок, в котором он проходит по alphas; для сопоставления с матрицей MSE лучше использовать переменную регрессора alphas_.

# %% [markdown]
# Обучите регрессор `LassoCV` на всех параметрах регуляризации из alpha. Постройте график _усредненного_ по строкам `MSE` в зависимости от `alpha` (используйте для этого функцию `create_plot`).
#
# Выведите выбранное `alpha`, а также пары "признак-коэффициент" для обученного вектора коэффициентов.

# %%
def create_plot(data, title, xlabel, ylabel, figsize=None):
    size = figsize or (15, 5)
    plt.figure(figsize=size)

    x = list(map(lambda e: e[0], data))
    y = list(map(lambda e: e[1], data))
    plt.plot(x, y)

    plt.title(title)
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)

    plt.grid()
    plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LassoCV

alphas = np.arange(1, 100, 5)

regressor = LassoCV(alphas=alphas, cv=3)

regressor.fit(X, y)  # Подставьте вместо X и y ваши данные

data = list(zip(regressor.alphas_, np.mean(regressor.mse_path_, axis=1)))
create_plot(list(data), "Lasso Cross-Validation", "Alpha", "Mean Squared Error")

print(f"Выбранное alpha: {regressor.alpha_}")

feature_names = ["season", "yr", "mnth", "holiday", "weekday", "workingday", "weathersit", 
                 "temp", "atemp", "hum", "windspeed(mph)", "windspeed(ms)"]
features_coefficients = list(zip(feature_names, regressor.coef_))
for feature, coef in features_coefficients:
    print(f"{feature}: {coef}")
# Out:
# Выбранное alpha: 6
# season: 532.0189828413535
# yr: 1015.0602226430595
# mnth: -100.03952614356629
# holiday: -83.29395987529904
# weekday: 132.50446549095795
# workingday: 51.557085614073735
# weathersit: -330.5598567399817
# temp: 370.67985503003405
# atemp: 581.396931065498
# hum: -140.00740550068844
# windspeed(mph): -191.77140847135036
# windspeed(ms): -2.6854702314758792e-08

# %% [markdown]
# Итак, мы выбрали некоторый параметр регуляризации. Давайте посмотрим, какие бы мы выбирали alpha, если бы делили выборку только один раз на обучающую и тестовую, то есть рассмотрим траектории MSE, соответствующие отдельным блокам выборки.

# %%
for i, mse_values in enumerate(regressor.mse_path_.T):
    plt.plot(regressor.alphas_, mse_values, label=f'Fold {i + 1}')

plt.xlabel('Alpha')
plt.ylabel('Mean Squared Error')
plt.title('Lasso Cross-Validation Paths for Each Fold')
plt.legend()
plt.show()

# %% [markdown]
# ### Задание 9
#
# Выведите значения `alpha`, соответствующие минимумам `MSE` на каждом разбиении (то есть по столбцам).
# На трех отдельных графиках визуализируйте столбцы `mse_path_`.

# %%
alphas = np.arange(1, 100, 5)

regressor = LassoCV(alphas=alphas, cv=3)

regressor.fit(X, y)

min_alpha_indices = np.argmin(regressor.mse_path_, axis=0)
min_alpha_values = regressor.alphas_[min_alpha_indices]

print("Alphas with minimum MSE:")
for i, alpha in enumerate(min_alpha_values):
    print(f"Fold {i + 1}: Alpha = {alpha}, MSE = {regressor.mse_path_[min_alpha_indices[i], i]}")

fig, axes = plt.subplots(3, 1, figsize=(10, 15))

for i, mse_values in enumerate(regressor.mse_path_.T):
    axes[i].plot(regressor.alphas_, mse_values, label=f'Fold {i + 1}')
    axes[i].set_xlabel('Alpha')
    axes[i].set_ylabel('Mean Squared Error')
    axes[i].set_title(f'Lasso Cross-Validation Paths - Fold {i + 1}')
    axes[i].legend()

plt.tight_layout()
plt.show()
# Out:
# Alphas with minimum MSE:
# Fold 1: Alpha = 6, MSE = 733725.7604052249
# Fold 2: Alpha = 1, MSE = 799433.1673691692
# Fold 3: Alpha = 51, MSE = 796979.8955193626

# %% [markdown]
# На каждом разбиении оптимальное значение `alpha` свое, и ему соответствует большое MSE на других разбиениях. Получается, что мы настраиваемся на конкретные обучающие и контрольные выборки. При выборе `alpha` на кросс-валидации мы выбираем нечто "среднее", что будет давать приемлемое значение метрики на разных разбиениях выборки.

# %% [markdown]
# ### Задание 10
#
# Наконец, как принято в анализе данных, давайте проинтерпретируем результат. Ответьте на следующие вопросы.

# %% [markdown]
# #### Вопрос 1
#
# В последней обученной модели выберите 4 признака с наибольшими (положительными) коэфициентами (и выпишите их), посмотрите на визуализации зависимостей `cnt` от этих признаков, которые мы рисовали в блоке "Знакомство с данными". Видна ли возрастающая линейная зависимость `cnt` от этих признаков по графикам? Логично ли утверждать (из здравого смысла), что чем больше значение этих признаков, тем больше людей захотят взять велосипеды?

# %% [markdown]
# __Ответ:__

# %%
features_coefficients = list(zip(feature_names, regressor.coef_))

sorted_coefficients = sorted(features_coefficients, key=lambda x: x[1], reverse=True)

top_positive_features = [feature for feature, coef in sorted_coefficients[:4]]
print("Top 4 features with the highest positive coefficients:")
print(top_positive_features)
# Out:
# Top 4 features with the highest positive coefficients:
# ['yr', 'atemp', 'season', 'temp']

# %% [raw]
# Топ-4 ознаки з найбільшими позитивними коефіцієнтами: yr, atemp, temp, season.
# Так, на графіках залежностей видно зростаючу лінійну залежність cnt від цих ознак, що логічно:
# збільшення року (yr), температури (atemp та temp), а також сезону (season) може сприяти більш активному
# використання велосипедів.

# %% [markdown]
# #### Вопрос 2
#
# Выберите 3 признака с наибольшими по модулю отрицательными коэффициентами (и выпишите их), посмотрите на соответствующие визуализации. Видна ли убывающая линейная зависимость? Логично ли утверждать, что чем больше величина этих признаков, тем меньше людей захотят взять велосипеды?

# %% [markdown]
# __Ответ:__

# %%
top_negative_features = [feature for feature, coef in sorted_coefficients[-3:]]
print("Top 3 features with the highest absolute negative coefficients:")
print(top_negative_features)
# Out:
# Top 3 features with the highest absolute negative coefficients:
# ['hum', 'windspeed(mph)', 'weathersit']

# %% [raw]
# Топ-3 ознаки з найбільшими за модулем негативними коефіцієнтами: weathersit, windspeed(mph), hum.
# На графіках видно спадна лінійна залежність cnt від цих ознак.
# Логічно стверджувати, що більш несприятливі погодні умови (weathersit), вища вологість (hum)
# і більша швидкість вітру (windspeed(mph)) можуть зменшити попит на велосипеди.

# %% [markdown]
# #### Вопрос 3
#
# Выпишите признаки с коэффициентами, близкими к нулю (< 1e-3). Как вы думаете, почему модель исключила их из модели (вновь посмотрите на графики)? Верно ли, что они никак не влияют на спрос на велосипеды?

# %% [markdown]
# __Ответ:__

# %%
zero_coefficient_features = [feature for feature, coef in sorted_coefficients if abs(coef) < 1e-3]
print("Features with coefficients close to zero:")
print(zero_coefficient_features)
# Out:
# Features with coefficients close to zero:
# ['windspeed(ms)']

# %% [raw]
# Ознаки з коефіцієнтами, близькими до нуля: windspeed(ms). Модель виключила цю ознаку, ймовірно, тому що вона по суті дублює інформацію, що міститься в windspeed(mph). Таким чином, ця ознака не значно впливає на попит на велосипеди і може бути виключений.

# %% [markdown]
# ### Заключение
# Итак, мы посмотрели, как можно следить за адекватностью линейной модели, как отбирать признаки и как грамотно, по возможности не настраиваясь на какую-то конкретную порцию данных, подбирать коэффициент регуляризации.
#
# Стоит отметить, что с помощью кросс-валидации удобно подбирать лишь небольшое число параметров (1, 2, максимум 3), потому что для каждой допустимой их комбинации нам приходится несколько раз обучать модель. Такой процесс занимает много времени, особенно если нужно обучаться на больших объемах данных.
